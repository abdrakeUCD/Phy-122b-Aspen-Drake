# %% [markdown]
# This notebook is for **geometry-specific analysis of the Cs runs**, especially the thickness-effect runs.
#
# It assumes you have already built:
# - `compton_analysis_outputs/compton_feature_fits_all.csv`
# - `manual_peak_fits_all.csv`
# - `processed_data/...`
#
# The goal here is not just to plot one thing, but to separate several physically different effects:
#
# 1. **front attenuation** of the main beam,
# 2. **behind-source backscatter enhancement**,
# 3. shifts in the **backscatter peak** and **Compton edge**,
# 4. changes in the **slope / width of the Compton continuum**,
# 5. changes in the **photopeak relative to the low-energy structure**.
#
# WARNING: the `in_front` runs where the 662 keV peak gets lost should not be forced into the same photopeak-based observables as the cleaner runs. For those, continuum-based observables are more trustworthy.

# %%
# -----------------------------
# IMPORTS
# -----------------------------

import re
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
plt.rcParams["figure.figsize"] = (9, 5)

# %%
# -----------------------------
# FILE LOCATIONS
# -----------------------------

ROOT = Path("processed_data")
COMPTON_MASTER = Path("compton_analysis_outputs") / "compton_feature_fits_all.csv"
MANUAL_PEAK_FILE = Path("peak_analysis_outputs") / "manual_peak_fits_all.csv"
BACKGROUND_FILE = ROOT / "calibration" / "background_550PM_feb26_213PM_mar3.csv"

print("Compton master exists:", COMPTON_MASTER.exists())
print("Manual peak file exists:", MANUAL_PEAK_FILE.exists())
print("Background exists:", BACKGROUND_FILE.exists())
# Out:
# Compton master exists: True
# Manual peak file exists: True
# Background exists: True

# %%
# -----------------------------
# LOAD TABLES
# -----------------------------

compton_df = pd.read_csv(COMPTON_MASTER)
peak_df = pd.read_csv(MANUAL_PEAK_FILE)

print("Compton rows:", len(compton_df))
print("Peak rows:", len(peak_df))

display(compton_df.head())
display(peak_df.head())
# Out:
# Compton rows: 38
# Peak rows: 138
#                                            file    day     feature_label  \
# 0   calibration/daily/Cs_21.9C_preamp0_mar5.csv   mar5  backscatter_peak
# 1   calibration/daily/Cs_21.9C_preamp0_mar5.csv   mar5      compton_edge
# 2   calibration/daily/Cs_22.0C_preamp0_mar3.csv   mar3  backscatter_peak
# 3   calibration/daily/Cs_22.0C_preamp0_mar3.csv   mar3      compton_edge
# 4  calibration/daily/Cs_22.4C_preamp0_feb26.csv  feb26  backscatter_peak
#
#    center_ADC  center_ADC_err  sigma_ADC  sigma_ADC_err  \
# 0  152.635832        5.983856  10.624223       9.856419
# 1  340.547030       23.226304  12.100073      37.412921
# 2  155.014473        5.257236  11.239558       8.076281
# 3  354.746429     2180.457833  39.426661    2840.375276
# 4  143.535067        3.679579   7.661727       5.157910
#
#    amplitude_counts_per_s  amplitude_counts_per_s_err  gaussian_area_counts  \
# 0                3.121502                    2.471694             83.128658
# 1                1.061078                    3.765257             32.182905
# 2                2.603258                    1.370986             73.342604
# 3                8.288705                 1444.012950            819.155963
# 4                4.234137                    1.942617             81.317042
#
#    gaussian_area_counts_err  fit_xmin  fit_xmax  background_slope  \
# 0                101.392320    132.99    177.87          0.014230
# 1                151.472478    313.83    358.71         -0.031632
# 2                 65.339936    130.35    183.15          0.007544
# 3             154429.384151    319.11    354.75         -0.092211
# 4                 66.247231    122.43    163.35          0.080216
#
#    background_slope_err  background_intercept  background_intercept_err  \
# 0              0.063609              2.922854                 11.555582
# 1              0.089709             13.955308                 27.213424
# 2              0.033468              2.775268                  5.980826
# 3             12.244989             26.786674               2903.329319
# 4              0.066423              0.456207                  9.307569
#
#    fit_chi2  fit_redchi2  compton_region_length_ADC  \
# 0  0.085901     0.002148                 187.911197
# 1  2.768360     0.069209                 187.911197
# 2  0.072134     0.001503                 199.731957
# 3  1.798890     0.059963                 199.731957
# 4  8.467742     0.235215                 196.968899
#
#    compton_region_length_ADC_err  compton_region_slope_counts_per_s_per_ADC  \
# 0                      23.984740                                  -0.011843
# 1                      23.984740                                  -0.011843
# 2                    2180.464171                                  -0.009451
# 3                    2180.464171                                  -0.009451
# 4                     187.543882                                  -0.020528
#
#    compton_region_slope_err  compton_region_intercept  \
# 0                  0.000815                  7.674373
# 1                  0.000815                  7.674373
# 2                  0.000618                  5.919690
# 3                  0.000618                  5.919690
# 4                  0.001182                 16.133728
#
#    compton_region_intercept_err  compton_region_redchi2  \
# 0                      0.210897                0.072974
# 1                      0.210897                0.072974
# 2                      0.166310                0.067545
# 3                      0.166310                0.067545
# 4                      0.300005                0.075876
#
#    compton_region_average_drop_per_ADC
# 0                            -0.011843
# 1                            -0.011843
# 2                            -0.009451
# 3                            -0.009451
# 4                            -0.020528
#                                                file  group_id  peak_in_group  \
# 0   calibration/daily/Co60_21.9C_preamp100_mar5.csv         1              1
# 1   calibration/daily/Co60_21.9C_preamp100_mar5.csv         1              2
# 2  calibration/daily/Co60_22.4C_preamp100_feb26.csv         1              1
# 3  calibration/daily/Co60_22.4C_preamp100_feb26.csv         1              2
# 4   calibration/daily/Co60_22.5C_preamp100_mar3.csv         1              1
#
#    n_peaks_in_group  theoretical_energy_keV  theoretical_energy_keV_err  \
# 0                 2                1173.228                       0.003
# 1                 2                1332.494                       0.002
# 2                 2                1173.228                       0.003
# 3                 2                1332.494                       0.002
# 4                 2                1173.228                       0.003
#
#    clicked_center_ADC  center_ADC  center_ADC_err  sigma_ADC  sigma_ADC_err  \
# 0                 652  649.075865        0.223619  14.749785       0.297055
# 1                 732  734.205555        0.282125  16.329201       0.369967
# 2                 652  651.142231        0.184083  14.864290       0.239054
# 3                 740  737.334233        0.229609  16.270415       0.269837
# 4                 645  648.684317        0.222826  14.592461       0.292220
#
#    amplitude_counts_per_s  amplitude_counts_per_s_err  gaussian_area_counts  \
# 0                5.958860                    0.087479            220.312327
# 1                5.032531                    0.083152            205.987725
# 2               14.550275                    0.172824            542.132295
# 3               12.265332                    0.158176            500.227869
# 4                4.466219                    0.065576            163.364814
#
#    fit_xmin  fit_xmax  background_slope  background_intercept
# 0       597       792         -0.005121              3.997337
# 1       597       792         -0.005121              3.997337
# 2       596       815         -0.011299              9.124645
# 3       596       815         -0.011299              9.124645
# 4       596       790         -0.003907              3.043445

# %%
# -----------------------------
# PARSE GEOMETRY METADATA
# -----------------------------

def _extract_float(pattern, text):
    m = re.search(pattern, str(text))
    if not m:
        return np.nan
    try:
        return float(m.group(1))
    except Exception:
        return np.nan

def parse_geometry_info(relpath):
    rel = Path(relpath).as_posix()
    lower = rel.lower()
    name = Path(rel).name

    if "thickness_effects_behind" in lower:
        geometry_position = "behind"
    elif "thickness_effects_in_front" in lower:
        geometry_position = "in_front"
    else:
        geometry_position = "standard"

    if "/pb" in lower or name.startswith("Pb_") or name.startswith("pb_"):
        material = "Pb"
    elif "/al" in lower or name.startswith("Al_") or name.startswith("al_"):
        material = "Al"
    else:
        material = "none"

    if "control" in lower or "booster" in lower:
        run_role = "control"
    else:
        run_role = "measurement"

    thickness_cm = _extract_float(r"([0-9]+(?:\.[0-9]+)?)cmthick", name)
    pmt_distance_cm = _extract_float(r"([0-9]+(?:\.[0-9]+)?)cmpmt", name)
    source_to_pmt_cm = _extract_float(r"([0-9]+(?:\.[0-9]+)?)cmpmt_tosource", name)

    if np.isnan(source_to_pmt_cm) and geometry_position == "in_front":
        source_to_pmt_cm = pmt_distance_cm

    if "feb_26" in lower:
        day = "feb26"
    elif "mar_3" in lower:
        day = "mar3"
    elif "mar_5" in lower:
        day = "mar5"
    elif "feb_24" in lower:
        day = "feb24"
    else:
        day = None

    return {
        "geometry_position": geometry_position,
        "material": material,
        "run_role": run_role,
        "thickness_cm": thickness_cm,
        "pmt_distance_cm": pmt_distance_cm,
        "source_to_pmt_cm": source_to_pmt_cm,
        "day": day,
    }

geom_meta = pd.DataFrame([{"file": f, **parse_geometry_info(f)} for f in sorted(set(compton_df["file"]))])
display(geom_meta.head(20))
# Out:
#                                                  file geometry_position  \
# 0         calibration/daily/Cs_21.9C_preamp0_mar5.csv          standard
# 1         calibration/daily/Cs_22.0C_preamp0_mar3.csv          standard
# 2        calibration/daily/Cs_22.4C_preamp0_feb26.csv          standard
# 3   calibration/feb_24/preamp_0/Cs_22.1C_preamp0_f...          standard
# 4     cs gain setting/Cs_possible_calcurve_feb_24.csv          standard
# 5                 cs gain setting/Cs_trial_feb_19.csv          standard
# 6           data/feb_26/cs137/Cs_22.4C_feb26_run1.csv          standard
# 7             data/mar_3/cs137/Cs_22.5C_mar3_run1.csv          standard
# 8             data/mar_5/cs137/Cs_21.9C_mar5_run1.csv          standard
# 9   data/thickness_effects_behind/Al thickness/Al_...            behind
# 10  data/thickness_effects_behind/Al thickness/Al_...            behind
# 11  data/thickness_effects_behind/Al thickness/Al_...            behind
# 12  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 13  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 14  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 15  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 16  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 17  data/thickness_effects_in_front/Pb_11cmpmt_tos...          in_front
# 18  data/thickness_effects_in_front/Pb_11cmpmt_tos...          in_front
#
#    material     run_role  thickness_cm  pmt_distance_cm  source_to_pmt_cm  \
# 0      none  measurement           NaN              NaN               NaN
# 1      none  measurement           NaN              NaN               NaN
# 2      none  measurement           NaN              NaN               NaN
# 3      none  measurement           NaN              NaN               NaN
# 4      none  measurement           NaN              NaN               NaN
# 5      none  measurement           NaN              NaN               NaN
# 6      none  measurement           NaN              NaN               NaN
# 7      none  measurement           NaN              NaN               NaN
# 8      none  measurement           NaN              NaN               NaN
# 9        Al  measurement           1.3             16.0               NaN
# 10       Al  measurement          14.7             16.0               NaN
# 11       Al  measurement           2.3             16.0               NaN
# 12       Pb  measurement           0.1             13.2               NaN
# 13       Pb  measurement          14.5             13.2               NaN
# 14       Pb  measurement           7.5             13.2               NaN
# 15       Pb  measurement           4.8             15.3               NaN
# 16       Pb      control           NaN              NaN               NaN
# 17       Pb  measurement          10.0             11.0              11.0
# 18       Pb  measurement           5.0             11.0              11.0
#
#       day
# 0    None
# 1    None
# 2    None
# 3   feb24
# 4   feb24
# 5    None
# 6   feb26
# 7    mar3
# 8    mar5
# 9    None
# 10   None
# 11   None
# 12   None
# 13   None
# 14   None
# 15   None
# 16   None
# 17   None
# 18   None

# %%
# -----------------------------
# WIDE COMPTON TABLE
# -----------------------------

wide = (
    compton_df
    .pivot_table(
        index="file",
        columns="feature_label",
        values=[
            "center_ADC",
            "center_ADC_err",
            "sigma_ADC",
            "sigma_ADC_err",
            "amplitude_counts_per_s",
            "amplitude_counts_per_s_err",
            "gaussian_area_counts",
            "gaussian_area_counts_err",
            "fit_redchi2",
            "compton_region_length_ADC",
            "compton_region_length_ADC_err",
            "compton_region_slope_counts_per_s_per_ADC",
            "compton_region_slope_err",
            "compton_region_redchi2",
            "compton_region_average_drop_per_ADC",
        ],
        aggfunc="first",
    )
)

wide.columns = [
    f"{a}__{b}" if isinstance(b, str) and b else str(a)
    for a, b in wide.columns.to_flat_index()
]
wide = wide.reset_index()

geom_df = wide.merge(geom_meta, on="file", how="left")
display(geom_df.head())
# Out:
#                                                 file  \
# 0        calibration/daily/Cs_21.9C_preamp0_mar5.csv
# 1        calibration/daily/Cs_22.0C_preamp0_mar3.csv
# 2       calibration/daily/Cs_22.4C_preamp0_feb26.csv
# 3  calibration/feb_24/preamp_0/Cs_22.1C_preamp0_f...
# 4    cs gain setting/Cs_possible_calcurve_feb_24.csv
#
#    amplitude_counts_per_s__backscatter_peak  \
# 0                                  3.121502
# 1                                  2.603258
# 2                                  4.234137
# 3                                  4.578092
# 4                                  5.403736
#
#    amplitude_counts_per_s__compton_edge  \
# 0                              1.061078
# 1                              8.288705
# 2                              4.277581
# 3                              0.651680
# 4                              1.400280
#
#    amplitude_counts_per_s_err__backscatter_peak  \
# 0                                      2.471694
# 1                                      1.370986
# 2                                      1.942617
# 3                                      1.638804
# 4                                      4.718535
#
#    amplitude_counts_per_s_err__compton_edge  center_ADC__backscatter_peak  \
# 0                                  3.765257                    152.635832
# 1                               1444.012950                    155.014473
# 2                                114.711629                    143.535067
# 3                                  2.024122                    146.828851
# 4                                  7.716039                    144.965989
#
#    center_ADC__compton_edge  center_ADC_err__backscatter_peak  \
# 0                340.547030                          5.983856
# 1                354.746429                          5.257236
# 2                340.503966                          3.679579
# 3                332.599207                          3.600527
# 4                336.736137                          5.725635
#
#    center_ADC_err__compton_edge  \
# 0                     23.226304
# 1                   2180.457833
# 2                    187.507783
# 3                     16.366037
# 4                     30.609912
#
#    compton_region_average_drop_per_ADC__backscatter_peak  \
# 0                                          -0.011843
# 1                                          -0.009451
# 2                                          -0.020528
# 3                                          -0.019199
# 4                                          -0.018930
#
#    compton_region_average_drop_per_ADC__compton_edge  \
# 0                                          -0.011843
# 1                                          -0.009451
# 2                                          -0.020528
# 3                                          -0.019199
# 4                                          -0.018930
#
#    compton_region_length_ADC__backscatter_peak  \
# 0                                   187.911197
# 1                                   199.731957
# 2                                   196.968899
# 3                                   185.770356
# 4                                   191.770148
#
#    compton_region_length_ADC__compton_edge  \
# 0                               187.911197
# 1                               199.731957
# 2                               196.968899
# 3                               185.770356
# 4                               191.770148
#
#    compton_region_length_ADC_err__backscatter_peak  \
# 0                                        23.984740
# 1                                      2180.464171
# 2                                       187.543882
# 3                                        16.757415
# 4                                        31.140803
#
#    compton_region_length_ADC_err__compton_edge  \
# 0                                    23.984740
# 1                                  2180.464171
# 2                                   187.543882
# 3                                    16.757415
# 4                                    31.140803
#
#    compton_region_redchi2__backscatter_peak  \
# 0                                  0.072974
# 1                                  0.067545
# 2                                  0.075876
# 3                                  0.075770
# 4                                  0.083252
#
#    compton_region_redchi2__compton_edge  \
# 0                              0.072974
# 1                              0.067545
# 2                              0.075876
# 3                              0.075770
# 4                              0.083252
#
#    compton_region_slope_counts_per_s_per_ADC__backscatter_peak  \
# 0                                          -0.011843
# 1                                          -0.009451
# 2                                          -0.020528
# 3                                          -0.019199
# 4                                          -0.018930
#
#    compton_region_slope_counts_per_s_per_ADC__compton_edge  \
# 0                                          -0.011843
# 1                                          -0.009451
# 2                                          -0.020528
# 3                                          -0.019199
# 4                                          -0.018930
#
#    compton_region_slope_err__backscatter_peak  \
# 0                                    0.000815
# 1                                    0.000618
# 2                                    0.001182
# 3                                    0.001151
# 4                                    0.001155
#
#    compton_region_slope_err__compton_edge  fit_redchi2__backscatter_peak  \
# 0                                0.000815                       0.002148
# 1                                0.000618                       0.001503
# 2                                0.001182                       0.235215
# 3                                0.001151                       0.141410
# 4                                0.001155                       0.165788
#
#    fit_redchi2__compton_edge  gaussian_area_counts__backscatter_peak  \
# 0                   0.069209                               83.128658
# 1                   0.059963                               73.342604
# 2                   0.053216                               81.317042
# 3                   0.062242                              113.612982
# 4                   0.058936                              149.777887
#
#    gaussian_area_counts__compton_edge  \
# 0                           32.182905
# 1                          819.155963
# 2                          194.538697
# 3                            9.340201
# 4                           36.045472
#
#    gaussian_area_counts_err__backscatter_peak  \
# 0                                  101.392320
# 1                                   65.339936
# 2                                   66.247231
# 3                                   71.180257
# 4                                  186.460818
#
#    gaussian_area_counts_err__compton_edge  sigma_ADC__backscatter_peak  \
# 0                              151.472478                    10.624223
# 1                           154429.384151                    11.239558
# 2                             5675.833450                     7.661727
# 3                               48.028259                     9.900418
# 4                              248.080973                    11.057671
#
#    sigma_ADC__compton_edge  sigma_ADC_err__backscatter_peak  \
# 0                12.100073                         9.856419
# 1                39.426661                         8.076281
# 2                18.143366                         5.157910
# 3                 5.717835                         5.090598
# 4                10.269418                         9.811705
#
#    sigma_ADC_err__compton_edge geometry_position material     run_role  \
# 0                    37.412921          standard     none  measurement
# 1                  2840.375276          standard     none  measurement
# 2                   208.516451          standard     none  measurement
# 3                    23.431925          standard     none  measurement
# 4                    42.346937          standard     none  measurement
#
#    thickness_cm  pmt_distance_cm  source_to_pmt_cm    day
# 0           NaN              NaN               NaN   None
# 1           NaN              NaN               NaN   None
# 2           NaN              NaN               NaN   None
# 3           NaN              NaN               NaN  feb24
# 4           NaN              NaN               NaN  feb24

# %%
# -----------------------------
# PHOTOPEAK TABLE FROM MANUAL PEAK FITS
# -----------------------------

photopeak_df = peak_df.copy()

# keep only likely Cs photopeak rows
photopeak_df = photopeak_df[
    np.isfinite(photopeak_df["theoretical_energy_keV"]) &
    np.isclose(photopeak_df["theoretical_energy_keV"], 661.657, atol=5.0)
].copy()

photopeak_df = (
    photopeak_df.sort_values(["file", "amplitude_counts_per_s"], ascending=[True, False])
    .drop_duplicates(subset=["file"])
)

photopeak_df = photopeak_df[[
    "file",
    "center_ADC",
    "center_ADC_err",
    "sigma_ADC",
    "sigma_ADC_err",
    "amplitude_counts_per_s",
    "amplitude_counts_per_s_err",
    "gaussian_area_counts",
]].rename(columns={
    "center_ADC": "photopeak_center_ADC",
    "center_ADC_err": "photopeak_center_ADC_err",
    "sigma_ADC": "photopeak_sigma_ADC",
    "sigma_ADC_err": "photopeak_sigma_ADC_err",
    "amplitude_counts_per_s": "photopeak_amplitude_counts_per_s",
    "amplitude_counts_per_s_err": "photopeak_amplitude_counts_per_s_err",
    "gaussian_area_counts": "photopeak_area_counts",
})

analysis_df = geom_df.merge(photopeak_df, on="file", how="left")
display(analysis_df.head(20))
# Out:
#                                                  file  \
# 0         calibration/daily/Cs_21.9C_preamp0_mar5.csv
# 1         calibration/daily/Cs_22.0C_preamp0_mar3.csv
# 2        calibration/daily/Cs_22.4C_preamp0_feb26.csv
# 3   calibration/feb_24/preamp_0/Cs_22.1C_preamp0_f...
# 4     cs gain setting/Cs_possible_calcurve_feb_24.csv
# 5                 cs gain setting/Cs_trial_feb_19.csv
# 6           data/feb_26/cs137/Cs_22.4C_feb26_run1.csv
# 7             data/mar_3/cs137/Cs_22.5C_mar3_run1.csv
# 8             data/mar_5/cs137/Cs_21.9C_mar5_run1.csv
# 9   data/thickness_effects_behind/Al thickness/Al_...
# 10  data/thickness_effects_behind/Al thickness/Al_...
# 11  data/thickness_effects_behind/Al thickness/Al_...
# 12  data/thickness_effects_behind/Pb thickness/Pb_...
# 13  data/thickness_effects_behind/Pb thickness/Pb_...
# 14  data/thickness_effects_behind/Pb thickness/Pb_...
# 15  data/thickness_effects_behind/Pb thickness/Pb_...
# 16  data/thickness_effects_behind/Pb thickness/Pb_...
# 17  data/thickness_effects_in_front/Pb_11cmpmt_tos...
# 18  data/thickness_effects_in_front/Pb_11cmpmt_tos...
#
#     amplitude_counts_per_s__backscatter_peak  \
# 0                                   3.121502
# 1                                   2.603258
# 2                                   4.234137
# 3                                   4.578092
# 4                                   5.403736
# 5                                 324.216360
# 6                                  13.158523
# 7                                   2.785158
# 8                                   3.019744
# 9                                   4.048518
# 10                                  3.490083
# 11                                  8.072269
# 12                                  3.527404
# 13                                  3.275275
# 14                                  3.168714
# 15                                  3.432435
# 16                                  3.777753
# 17                                  0.535890
# 18                                  0.611064
#
#     amplitude_counts_per_s__compton_edge  \
# 0                               1.061078
# 1                               8.288705
# 2                               4.277581
# 3                               0.651680
# 4                               1.400280
# 5                              36.994570
# 6                               1.317219
# 7                               5.592583
# 8                               7.865024
# 9                              14.638799
# 10                              3.070915
# 11                             34.903992
# 12                             14.637174
# 13                             10.087662
# 14                             20.155584
# 15                             16.576558
# 16                              7.681816
# 17                              0.531677
# 18                              1.400700
#
#     amplitude_counts_per_s_err__backscatter_peak  \
# 0                                       2.471694
# 1                                       1.370986
# 2                                       1.942617
# 3                                       1.638804
# 4                                       4.718535
# 5                                    2046.278361
# 6                                      60.446842
# 7                                       3.259084
# 8                                       3.979276
# 9                                       2.219079
# 10                                      2.628809
# 11                                      2.942048
# 12                                      2.006003
# 13                                      2.185407
# 14                                      2.191596
# 15                                      2.014505
# 16                                      1.906136
# 17                                      0.349581
# 18                                      0.521894
#
#     amplitude_counts_per_s_err__compton_edge  center_ADC__backscatter_peak  \
# 0                                   3.765257                    152.635832
# 1                                1444.012950                    155.014473
# 2                                 114.711629                    143.535067
# 3                                   2.024122                    146.828851
# 4                                   7.716039                    144.965989
# 5                                1002.896916                    129.030000
# 6                                   2.053617                    138.219695
# 7                                6849.697023                    154.441353
# 8                                 599.685286                    151.985613
# 9                                1490.175750                    138.811329
# 10                                 96.074683                    137.046783
# 11                               2065.683314                    138.980916
# 12                               1360.319457                    139.186077
# 13                                266.530931                    138.055778
# 14                                972.862200                    138.815487
# 15                                428.710873                    139.123870
# 16                                209.071574                    139.601856
# 17                                  0.665223                     68.335339
# 18                                  0.994172                     67.819415
#
#     center_ADC__compton_edge  center_ADC_err__backscatter_peak  \
# 0                 340.547030                          5.983856
# 1                 354.746429                          5.257236
# 2                 340.503966                          3.679579
# 3                 332.599207                          3.600527
# 4                 336.736137                          5.725635
# 5                 261.376175                         48.615707
# 6                 333.658943                         29.478377
# 7                 324.390000                          8.981128
# 8                 354.748548                          7.095168
# 9                 341.550000                          5.314869
# 10                338.713904                          3.089282
# 11                342.870000                          3.437548
# 12                342.870000                          3.937758
# 13                339.431919                          3.586943
# 14                344.187912                          3.920621
# 15                342.692715                          4.139858
# 16                336.884991                          4.274703
# 17                152.050693                          3.110637
# 18                154.585528                          4.305021
#
#     center_ADC_err__compton_edge  \
# 0                      23.226304
# 1                    2180.457833
# 2                     187.507783
# 3                      16.366037
# 4                      30.609912
# 5                     148.580229
# 6                      12.409968
# 7                   13234.728968
# 8                     712.153671
# 9                     964.714230
# 10                    127.586780
# 11                    623.767310
# 12                    752.698403
# 13                    205.317900
# 14                    551.230117
# 15                    267.112945
# 16                    207.864654
# 17                      8.662329
# 18                      6.030741
#
#     compton_region_average_drop_per_ADC__backscatter_peak  \
# 0                                           -0.011843
# 1                                           -0.009451
# 2                                           -0.020528
# 3                                           -0.019199
# 4                                           -0.018930
# 5                                           -0.104232
# 6                                           -0.023579
# 7                                           -0.012078
# 8                                           -0.011318
# 9                                           -0.026486
# 10                                          -0.017245
# 11                                          -0.057499
# 12                                          -0.025579
# 13                                          -0.025620
# 14                                          -0.026126
# 15                                          -0.026072
# 16                                          -0.025674
# 17                                           0.003065
# 18                                           0.008833
#
#     compton_region_average_drop_per_ADC__compton_edge  \
# 0                                           -0.011843
# 1                                           -0.009451
# 2                                           -0.020528
# 3                                           -0.019199
# 4                                           -0.018930
# 5                                           -0.104232
# 6                                           -0.023579
# 7                                           -0.012078
# 8                                           -0.011318
# 9                                           -0.026486
# 10                                          -0.017245
# 11                                          -0.057499
# 12                                          -0.025579
# 13                                          -0.025620
# 14                                          -0.026126
# 15                                          -0.026072
# 16                                          -0.025674
# 17                                           0.003065
# 18                                           0.008833
#
#     compton_region_length_ADC__backscatter_peak  \
# 0                                    187.911197
# 1                                    199.731957
# 2                                    196.968899
# 3                                    185.770356
# 4                                    191.770148
# 5                                    132.346175
# 6                                    195.439247
# 7                                    169.948647
# 8                                    202.762934
# 9                                    202.738671
# 10                                   201.667121
# 11                                   203.889084
# 12                                   203.683923
# 13                                   201.376141
# 14                                   205.372426
# 15                                   203.568845
# 16                                   197.283135
# 17                                    83.715354
# 18                                    86.766113
#
#     compton_region_length_ADC__compton_edge  \
# 0                                187.911197
# 1                                199.731957
# 2                                196.968899
# 3                                185.770356
# 4                                191.770148
# 5                                132.346175
# 6                                195.439247
# 7                                169.948647
# 8                                202.762934
# 9                                202.738671
# 10                               201.667121
# 11                               203.889084
# 12                               203.683923
# 13                               201.376141
# 14                               205.372426
# 15                               203.568845
# 16                               197.283135
# 17                                83.715354
# 18                                86.766113
#
#     compton_region_length_ADC_err__backscatter_peak  \
# 0                                         23.984740
# 1                                       2180.464171
# 2                                        187.543882
# 3                                         16.757415
# 4                                         31.140803
# 5                                        156.331607
# 6                                         31.984090
# 7                                      13234.732016
# 8                                        712.189014
# 9                                        964.728870
# 10                                       127.624175
# 11                                       623.776782
# 12                                       752.708704
# 13                                       205.349230
# 14                                       551.244060
# 15                                       267.145024
# 16                                       207.908604
# 17                                         9.203913
# 18                                         7.409659
#
#     compton_region_length_ADC_err__compton_edge  \
# 0                                     23.984740
# 1                                   2180.464171
# 2                                    187.543882
# 3                                     16.757415
# 4                                     31.140803
# 5                                    156.331607
# 6                                     31.984090
# 7                                  13234.732016
# 8                                    712.189014
# 9                                    964.728870
# 10                                   127.624175
# 11                                   623.776782
# 12                                   752.708704
# 13                                   205.349230
# 14                                   551.244060
# 15                                   267.145024
# 16                                   207.908604
# 17                                     9.203913
# 18                                     7.409659
#
#     compton_region_redchi2__backscatter_peak  \
# 0                                   0.072974
# 1                                   0.067545
# 2                                   0.075876
# 3                                   0.075770
# 4                                   0.083252
# 5                                   0.309695
# 6                                   0.081006
# 7                                   0.065537
# 8                                   0.077643
# 9                                   0.080669
# 10                                  0.692234
# 11                                  0.170871
# 12                                  0.080284
# 13                                  0.082620
# 14                                  0.081561
# 15                                  0.078605
# 16                                  0.080242
# 17                                  0.048673
# 18                                  0.062872
#
#     compton_region_redchi2__compton_edge  \
# 0                               0.072974
# 1                               0.067545
# 2                               0.075876
# 3                               0.075770
# 4                               0.083252
# 5                               0.309695
# 6                               0.081006
# 7                               0.065537
# 8                               0.077643
# 9                               0.080669
# 10                              0.692234
# 11                              0.170871
# 12                              0.080284
# 13                              0.082620
# 14                              0.081561
# 15                              0.078605
# 16                              0.080242
# 17                              0.048673
# 18                              0.062872
#
#     compton_region_slope_counts_per_s_per_ADC__backscatter_peak  \
# 0                                           -0.011843
# 1                                           -0.009451
# 2                                           -0.020528
# 3                                           -0.019199
# 4                                           -0.018930
# 5                                           -0.104232
# 6                                           -0.023579
# 7                                           -0.012078
# 8                                           -0.011318
# 9                                           -0.026486
# 10                                          -0.017245
# 11                                          -0.057499
# 12                                          -0.025579
# 13                                          -0.025620
# 14                                          -0.026126
# 15                                          -0.026072
# 16                                          -0.025674
# 17                                           0.003065
# 18                                           0.008833
#
#     compton_region_slope_counts_per_s_per_ADC__compton_edge  \
# 0                                           -0.011843
# 1                                           -0.009451
# 2                                           -0.020528
# 3                                           -0.019199
# 4                                           -0.018930
# 5                                           -0.104232
# 6                                           -0.023579
# 7                                           -0.012078
# 8                                           -0.011318
# 9                                           -0.026486
# 10                                          -0.017245
# 11                                          -0.057499
# 12                                          -0.025579
# 13                                          -0.025620
# 14                                          -0.026126
# 15                                          -0.026072
# 16                                          -0.025674
# 17                                           0.003065
# 18                                           0.008833
#
#     compton_region_slope_err__backscatter_peak  \
# 0                                     0.000815
# 1                                     0.000618
# 2                                     0.001182
# 3                                     0.001151
# 4                                     0.001155
# 5                                     0.008247
# 6                                     0.001248
# 7                                     0.000790
# 8                                     0.000738
# 9                                     0.001427
# 10                                    0.004611
# 11                                    0.002952
# 12                                    0.001411
# 13                                    0.001458
# 14                                    0.001389
# 15                                    0.001408
# 16                                    0.001478
# 17                                    0.000664
# 18                                    0.001158
#
#     compton_region_slope_err__compton_edge  fit_redchi2__backscatter_peak  \
# 0                                 0.000815                       0.002148
# 1                                 0.000618                       0.001503
# 2                                 0.001182                       0.235215
# 3                                 0.001151                       0.141410
# 4                                 0.001155                       0.165788
# 5                                 0.008247                       0.915242
# 6                                 0.001248                       0.229869
# 7                                 0.000790                       0.001869
# 8                                 0.000738                       0.001107
# 9                                 0.001427                       0.323208
# 10                                0.004611                       0.475758
# 11                                0.002952                       0.684846
# 12                                0.001411                       0.351889
# 13                                0.001458                       0.374120
# 14                                0.001389                       0.443222
# 15                                0.001408                       0.341403
# 16                                0.001478                       0.323908
# 17                                0.000664                       0.010818
# 18                                0.001158                       0.002357
#
#     fit_redchi2__compton_edge  gaussian_area_counts__backscatter_peak  \
# 0                    0.069209                               83.128658
# 1                    0.059963                               73.342604
# 2                    0.053216                               81.317042
# 3                    0.062242                              113.612982
# 4                    0.058936                              149.777887
# 5                    0.246486                            17674.477357
# 6                    0.053140                              520.421504
# 7                    0.001184                               82.636175
# 8                    0.062717                               74.841867
# 9                    0.053200                               98.094001
# 10                   0.001853                               32.320270
# 11                   0.089305                              179.208855
# 12                   0.062548                               54.387575
# 13                   0.049825                               39.555142
# 14                   0.039235                               39.193752
# 15                   0.039631                               54.172024
# 16                   0.051183                               71.386736
# 17                   0.013742                                6.560725
# 18                   0.001779                                6.880330
#
#     gaussian_area_counts__compton_edge  \
# 0                            32.182905
# 1                           819.155963
# 2                           194.538697
# 3                             9.340201
# 4                            36.045472
# 5                          1410.345279
# 6                            29.065675
# 7                           603.359717
# 8                           524.634423
# 9                          1002.656524
# 10                           88.549909
# 11                         2655.875777
# 12                          848.548404
# 13                          531.705236
# 14                         1641.094183
# 15                         1212.675850
# 16                          400.562388
# 17                           10.805569
# 18                           35.076055
#
#     gaussian_area_counts_err__backscatter_peak  \
# 0                                   101.392320
# 1                                    65.339936
# 2                                    66.247231
# 3                                    71.180257
# 4                                   186.460818
# 5                                118870.298090
# 6                                  2664.166427
# 7                                   131.423409
# 8                                   142.810402
# 9                                    94.084730
# 10                                   39.722989
# 11                                  116.482284
# 12                                   52.456229
# 13                                   43.873896
# 14                                   46.228691
# 15                                   54.044612
# 16                                   62.920942
# 17                                    6.112156
# 18                                    9.843720
#
#     gaussian_area_counts_err__compton_edge  sigma_ADC__backscatter_peak  \
# 0                               151.472478                    10.624223
# 1                            154429.384151                    11.239558
# 2                              5675.833450                     7.661727
# 3                                48.028259                     9.900418
# 4                               248.080973                    11.057671
# 5                             40897.405764                    21.748120
# 6                                73.918192                    15.778225
# 7                            811400.114708                    11.836694
# 8                             42566.450815                     9.887456
# 9                            109120.752945                     9.666216
# 10                             3127.782301                     3.694446
# 11                           167885.262392                     8.856740
# 12                            83928.564866                     6.151125
# 13                            15169.608801                     4.817983
# 14                            84403.926542                     4.934509
# 15                            33881.357814                     6.296263
# 16                            11872.908716                     7.538659
# 17                               20.891370                     4.884119
# 18                               37.679094                     4.491925
#
#     sigma_ADC__compton_edge  sigma_ADC_err__backscatter_peak  \
# 0                 12.100073                         9.856419
# 1                 39.426661                         8.076281
# 2                 18.143366                         5.157910
# 3                  5.717835                         5.090598
# 4                 10.269418                         9.811705
# 5                 15.208891                        50.530056
# 6                  8.803037                        35.647062
# 7                 43.040169                        12.748785
# 8                 26.611343                        13.645441
# 9                 27.324789                         7.608055
# 10                11.503510                         3.587993
# 11                30.355872                         4.766548
# 12                23.127540                         4.791682
# 13                21.027638                         4.268942
# 14                32.482405                         4.714560
# 15                29.185050                         5.079515
# 16                20.802539                         5.448177
# 17                 8.107929                         3.248533
# 18                 9.990235                         5.155889
#
#     sigma_ADC_err__compton_edge geometry_position material     run_role  \
# 0                     37.412921          standard     none  measurement
# 1                   2840.375276          standard     none  measurement
# 2                    208.516451          standard     none  measurement
# 3                     23.431925          standard     none  measurement
# 4                     42.346937          standard     none  measurement
# 5                    156.569294          standard     none  measurement
# 6                     17.687157          standard     none  measurement
# 7                  23901.976809          standard     none  measurement
# 8                    738.118796          standard     none  measurement
# 9                   1051.857480            behind       Al  measurement
# 10                   188.632277            behind       Al  measurement
# 11                   674.256635            behind       Al  measurement
# 12                   782.854081            behind       Pb  measurement
# 13                   226.350251            behind       Pb  measurement
# 14                   576.903344            behind       Pb  measurement
# 15                   308.505030            behind       Pb  measurement
# 16                   244.224967            behind       Pb      control
# 17                    11.950730          in_front       Pb  measurement
# 18                     8.055374          in_front       Pb  measurement
#
#     thickness_cm  pmt_distance_cm  source_to_pmt_cm    day  \
# 0            NaN              NaN               NaN   None
# 1            NaN              NaN               NaN   None
# 2            NaN              NaN               NaN   None
# 3            NaN              NaN               NaN  feb24
# 4            NaN              NaN               NaN  feb24
# 5            NaN              NaN               NaN   None
# 6            NaN              NaN               NaN  feb26
# 7            NaN              NaN               NaN   mar3
# 8            NaN              NaN               NaN   mar5
# 9            1.3             16.0               NaN   None
# 10          14.7             16.0               NaN   None
# 11           2.3             16.0               NaN   None
# 12           0.1             13.2               NaN   None
# 13          14.5             13.2               NaN   None
# 14           7.5             13.2               NaN   None
# 15           4.8             15.3               NaN   None
# 16           NaN              NaN               NaN   None
# 17          10.0             11.0              11.0   None
# 18           5.0             11.0              11.0   None
#
#     photopeak_center_ADC  photopeak_center_ADC_err  photopeak_sigma_ADC  \
# 0             505.179638                  0.180231            14.941343
# 1             505.671076                  0.183272            14.848871
# 2             503.121706                  0.164891            15.484003
# 3             505.196312                  0.194260            15.245587
# 4                    NaN                       NaN                  NaN
# 5                    NaN                       NaN                  NaN
# 6             503.190803                  0.186243            15.472963
# 7             505.105909                  0.183004            14.809077
# 8             505.214458                  0.195275            14.953999
# 9             497.431835                  0.156028            16.396757
# 10            497.103930                  0.160251            16.377774
# 11            497.398950                  0.150498            16.416819
# 12            498.577074                  0.162766            16.352365
# 13            498.514084                  0.165536            16.359837
# 14            498.123897                  0.162116            16.333815
# 15            497.367840                  0.139453            16.394681
# 16            497.295100                  0.157354            16.345324
# 17                   NaN                       NaN                  NaN
# 18            507.869871                  0.243902            14.337768
#
#     photopeak_sigma_ADC_err  photopeak_amplitude_counts_per_s  \
# 0                  0.204523                         38.228217
# 1                  0.208210                         28.570616
# 2                  0.184904                         91.451228
# 3                  0.222905                         74.002003
# 4                       NaN                               NaN
# 5                       NaN                               NaN
# 6                  0.214779                         91.293221
# 7                  0.208049                         28.712067
# 8                  0.226796                         38.141283
# 9                  0.179698                        134.725861
# 10                 0.186275                        135.069816
# 11                 0.171472                        273.499122
# 12                 0.187125                        132.847706
# 13                 0.191339                        132.661850
# 14                 0.187325                        132.625576
# 15                 0.159812                        134.998596
# 16                 0.180800                        132.031780
# 17                      NaN                               NaN
# 18                 0.289455                          1.709237
#
#     photopeak_amplitude_counts_per_s_err  photopeak_area_counts
# 0                               0.406552            1431.738174
# 1                               0.309751            1063.415433
# 2                               0.857490            3549.463506
# 3                               0.826398            2827.988026
# 4                                    NaN                    NaN
# 5                                    NaN                    NaN
# 6                               0.963175            3540.804629
# 7                               0.311447            1065.816362
# 8                               0.437966            1429.692282
# 9                               1.123950            5537.310346
# 10                              1.158110            5545.019986
# 11                              2.199936           11254.725064
# 12                              1.158965            5445.334454
# 13                              1.175227            5440.200997
# 14                              1.152528            5430.062726
# 15                              1.018854            5547.817323
# 16                              1.113885            5409.560037
# 17                                   NaN                    NaN
# 18                              0.025474              61.429058

# %%
# -----------------------------
# DERIVED OBSERVABLES
# -----------------------------

analysis_df["backscatter_to_photopeak_area_ratio"] = (
    analysis_df["gaussian_area_counts__backscatter_peak"] /
    analysis_df["photopeak_area_counts"]
)

analysis_df["backscatter_to_photopeak_amp_ratio"] = (
    analysis_df["amplitude_counts_per_s__backscatter_peak"] /
    analysis_df["photopeak_amplitude_counts_per_s"]
)

analysis_df["edge_minus_backscatter_ADC"] = (
    analysis_df["center_ADC__compton_edge"] -
    analysis_df["center_ADC__backscatter_peak"]
)

analysis_df["photopeak_minus_edge_ADC"] = (
    analysis_df["photopeak_center_ADC"] -
    analysis_df["center_ADC__compton_edge"]
)

display(analysis_df[
    [
        "file",
        "geometry_position",
        "material",
        "thickness_cm",
        "center_ADC__backscatter_peak",
        "center_ADC__compton_edge",
        "photopeak_center_ADC",
        "backscatter_to_photopeak_area_ratio",
        "backscatter_to_photopeak_amp_ratio",
        "edge_minus_backscatter_ADC",
        "photopeak_minus_edge_ADC",
        "compton_region_slope_counts_per_s_per_ADC__backscatter_peak",
    ]
].head(20))
# Out:
#                                                  file geometry_position  \
# 0         calibration/daily/Cs_21.9C_preamp0_mar5.csv          standard
# 1         calibration/daily/Cs_22.0C_preamp0_mar3.csv          standard
# 2        calibration/daily/Cs_22.4C_preamp0_feb26.csv          standard
# 3   calibration/feb_24/preamp_0/Cs_22.1C_preamp0_f...          standard
# 4     cs gain setting/Cs_possible_calcurve_feb_24.csv          standard
# 5                 cs gain setting/Cs_trial_feb_19.csv          standard
# 6           data/feb_26/cs137/Cs_22.4C_feb26_run1.csv          standard
# 7             data/mar_3/cs137/Cs_22.5C_mar3_run1.csv          standard
# 8             data/mar_5/cs137/Cs_21.9C_mar5_run1.csv          standard
# 9   data/thickness_effects_behind/Al thickness/Al_...            behind
# 10  data/thickness_effects_behind/Al thickness/Al_...            behind
# 11  data/thickness_effects_behind/Al thickness/Al_...            behind
# 12  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 13  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 14  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 15  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 16  data/thickness_effects_behind/Pb thickness/Pb_...            behind
# 17  data/thickness_effects_in_front/Pb_11cmpmt_tos...          in_front
# 18  data/thickness_effects_in_front/Pb_11cmpmt_tos...          in_front
#
#    material  thickness_cm  center_ADC__backscatter_peak  \
# 0      none           NaN                    152.635832
# 1      none           NaN                    155.014473
# 2      none           NaN                    143.535067
# 3      none           NaN                    146.828851
# 4      none           NaN                    144.965989
# 5      none           NaN                    129.030000
# 6      none           NaN                    138.219695
# 7      none           NaN                    154.441353
# 8      none           NaN                    151.985613
# 9        Al           1.3                    138.811329
# 10       Al          14.7                    137.046783
# 11       Al           2.3                    138.980916
# 12       Pb           0.1                    139.186077
# 13       Pb          14.5                    138.055778
# 14       Pb           7.5                    138.815487
# 15       Pb           4.8                    139.123870
# 16       Pb           NaN                    139.601856
# 17       Pb          10.0                     68.335339
# 18       Pb           5.0                     67.819415
#
#     center_ADC__compton_edge  photopeak_center_ADC  \
# 0                 340.547030            505.179638
# 1                 354.746429            505.671076
# 2                 340.503966            503.121706
# 3                 332.599207            505.196312
# 4                 336.736137                   NaN
# 5                 261.376175                   NaN
# 6                 333.658943            503.190803
# 7                 324.390000            505.105909
# 8                 354.748548            505.214458
# 9                 341.550000            497.431835
# 10                338.713904            497.103930
# 11                342.870000            497.398950
# 12                342.870000            498.577074
# 13                339.431919            498.514084
# 14                344.187912            498.123897
# 15                342.692715            497.367840
# 16                336.884991            497.295100
# 17                152.050693                   NaN
# 18                154.585528            507.869871
#
#     backscatter_to_photopeak_area_ratio  backscatter_to_photopeak_amp_ratio  \
# 0                              0.058061                            0.081654
# 1                              0.068969                            0.091117
# 2                              0.022910                            0.046299
# 3                              0.040174                            0.061864
# 4                                   NaN                                 NaN
# 5                                   NaN                                 NaN
# 6                              0.146978                            0.144135
# 7                              0.077533                            0.097003
# 8                              0.052348                            0.079173
# 9                              0.017715                            0.030050
# 10                             0.005829                            0.025839
# 11                             0.015923                            0.029515
# 12                             0.009988                            0.026552
# 13                             0.007271                            0.024689
# 14                             0.007218                            0.023892
# 15                             0.009765                            0.025426
# 16                             0.013196                            0.028612
# 17                                  NaN                                 NaN
# 18                             0.112004                            0.357507
#
#     edge_minus_backscatter_ADC  photopeak_minus_edge_ADC  \
# 0                   187.911197                164.632608
# 1                   199.731957                150.924647
# 2                   196.968899                162.617741
# 3                   185.770356                172.597105
# 4                   191.770148                       NaN
# 5                   132.346175                       NaN
# 6                   195.439247                169.531860
# 7                   169.948647                180.715909
# 8                   202.762934                150.465910
# 9                   202.738671                155.881835
# 10                  201.667121                158.390026
# 11                  203.889084                154.528950
# 12                  203.683923                155.707074
# 13                  201.376141                159.082165
# 14                  205.372426                153.935985
# 15                  203.568845                154.675125
# 16                  197.283135                160.410109
# 17                   83.715354                       NaN
# 18                   86.766113                353.284343
#
#     compton_region_slope_counts_per_s_per_ADC__backscatter_peak
# 0                                           -0.011843
# 1                                           -0.009451
# 2                                           -0.020528
# 3                                           -0.019199
# 4                                           -0.018930
# 5                                           -0.104232
# 6                                           -0.023579
# 7                                           -0.012078
# 8                                           -0.011318
# 9                                           -0.026486
# 10                                          -0.017245
# 11                                          -0.057499
# 12                                          -0.025579
# 13                                          -0.025620
# 14                                          -0.026126
# 15                                          -0.026072
# 16                                          -0.025674
# 17                                           0.003065
# 18                                           0.008833

# %% [markdown]
# ## Suggested analyses to prioritize (?)
#
# ### 1. Backscatter enhancement vs thickness
# For the `behind` runs, plot:
# - backscatter area,
# - backscatter amplitude,
# - backscatter / photopeak ratio,
#
# against thickness, separated by material.
#
# This is the cleanest direct test for whether adding material behind the source enhances return-scattered events without simply blocking the main beam.
#
# ### 2. Front-obstruction attenuation vs continuum reshaping
# For the `in_front` runs, the main 662 keV photopeak may fail as a stable observable. So emphasize:
# - backscatter center,
# - Compton-edge center,
# - Compton-region slope,
# - Compton-region length,
# - integrated low-energy continuum fractions,
#
# rather than only photopeak quantities.
#
# ### 3. Geometry comparison at matched material
# Compare `behind` vs `in_front` at similar Pb thickness. That separates two mechanisms:
# - extra scattered return into the detector,
# - direct attenuation between source and detector.
#
# ### 4. Stability checks using the ordinary Cs runs
# Use the ordinary `data/feb_26/cs137`, `mar_3/cs137`, and `mar_5/cs137` runs as your detector / electronics stability controls. If those are stable, then shifts in the thickness runs are more plausibly geometric than instrumental.

# %%
# -----------------------------
# PLOT HELPERS
# -----------------------------

def subset_plot_data(df, geometry_position=None, material=None, require_thickness=True):
    out = df.copy()
    if geometry_position is not None:
        out = out[out["geometry_position"] == geometry_position]
    if material is not None:
        out = out[out["material"] == material]
    if require_thickness:
        out = out[np.isfinite(out["thickness_cm"])]
    return out.sort_values("thickness_cm")

def scatter_with_error(df, xcol, ycol, yerrcol=None, title="", xlabel="", ylabel="", label_col="file"):
    fig, ax = plt.subplots(figsize=(9, 5))

    x = df[xcol].to_numpy(float)
    y = df[ycol].to_numpy(float)

    if yerrcol is not None and yerrcol in df.columns:
        yerr = df[yerrcol].to_numpy(float)
        ax.errorbar(x, y, yerr=yerr, fmt="o")
    else:
        ax.plot(x, y, "o")

    for _, row in df.iterrows():
        ax.annotate(
            Path(row[label_col]).stem,
            (row[xcol], row[ycol]),
            fontsize=8,
            alpha=0.8,
        )

    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(True, alpha=0.3)
    plt.show()

def grouped_line_plot(df, xcol, ycol, groupcol, title="", xlabel="", ylabel=""):
    fig, ax = plt.subplots(figsize=(9, 5))

    for key, sub in df.groupby(groupcol):
        sub = sub.sort_values(xcol)
        ax.plot(sub[xcol], sub[ycol], "o-", label=str(key))

    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(True, alpha=0.3)
    ax.legend()
    plt.show()

# %%
# -----------------------------
# ANALYSIS 1: BEHIND-RUN BACKSCATTER ENHANCEMENT
# -----------------------------

behind_df = subset_plot_data(analysis_df, geometry_position="behind")
display(behind_df[[
    "file",
    "material",
    "thickness_cm",
    "gaussian_area_counts__backscatter_peak",
    "amplitude_counts_per_s__backscatter_peak",
    "backscatter_to_photopeak_area_ratio",
    "backscatter_to_photopeak_amp_ratio",
]])

grouped_line_plot(
    behind_df,
    xcol="thickness_cm",
    ycol="gaussian_area_counts__backscatter_peak",
    groupcol="material",
    title="Behind runs: backscatter area vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Backscatter Gaussian area",
)

grouped_line_plot(
    behind_df,
    xcol="thickness_cm",
    ycol="backscatter_to_photopeak_area_ratio",
    groupcol="material",
    title="Behind runs: backscatter/photopeak area ratio vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Backscatter / photopeak area ratio",
)
# Out:
#                                                  file material  thickness_cm  \
# 12  data/thickness_effects_behind/Pb thickness/Pb_...       Pb           0.1
# 9   data/thickness_effects_behind/Al thickness/Al_...       Al           1.3
# 11  data/thickness_effects_behind/Al thickness/Al_...       Al           2.3
# 15  data/thickness_effects_behind/Pb thickness/Pb_...       Pb           4.8
# 14  data/thickness_effects_behind/Pb thickness/Pb_...       Pb           7.5
# 13  data/thickness_effects_behind/Pb thickness/Pb_...       Pb          14.5
# 10  data/thickness_effects_behind/Al thickness/Al_...       Al          14.7
#
#     gaussian_area_counts__backscatter_peak  \
# 12                               54.387575
# 9                                98.094001
# 11                              179.208855
# 15                               54.172024
# 14                               39.193752
# 13                               39.555142
# 10                               32.320270
#
#     amplitude_counts_per_s__backscatter_peak  \
# 12                                  3.527404
# 9                                   4.048518
# 11                                  8.072269
# 15                                  3.432435
# 14                                  3.168714
# 13                                  3.275275
# 10                                  3.490083
#
#     backscatter_to_photopeak_area_ratio  backscatter_to_photopeak_amp_ratio
# 12                             0.009988                            0.026552
# 9                              0.017715                            0.030050
# 11                             0.015923                            0.029515
# 15                             0.009765                            0.025426
# 14                             0.007218                            0.023892
# 13                             0.007271                            0.024689
# 10                             0.005829                            0.025839

# %%
# -----------------------------
# ANALYSIS 2: BACKSCATTER / EDGE POSITION SHIFTS
# -----------------------------

thickness_df = analysis_df[analysis_df["geometry_position"].isin(["behind", "in_front"])].copy()

grouped_line_plot(
    thickness_df,
    xcol="thickness_cm",
    ycol="center_ADC__backscatter_peak",
    groupcol="geometry_position",
    title="Backscatter center vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Backscatter center (ADC)",
)

grouped_line_plot(
    thickness_df,
    xcol="thickness_cm",
    ycol="center_ADC__compton_edge",
    groupcol="geometry_position",
    title="Compton-edge center vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Compton-edge center (ADC)",
)

# %%
# -----------------------------
# ANALYSIS 3: COMPTON-CONTINUUM SHAPE
# -----------------------------

# Note:
# after pivoting, the compton-region columns live under one feature branch.
# Either feature branch should hold the same per-file region metrics.
slope_col_candidates = [
    c for c in analysis_df.columns
    if c.startswith("compton_region_slope_counts_per_s_per_ADC")
]
length_col_candidates = [
    c for c in analysis_df.columns
    if c.startswith("compton_region_length_ADC")
]

print("Slope columns:", slope_col_candidates)
print("Length columns:", length_col_candidates)

slope_col = slope_col_candidates[0]
length_col = [c for c in length_col_candidates if not c.endswith("_err")][0]

grouped_line_plot(
    thickness_df,
    xcol="thickness_cm",
    ycol=slope_col,
    groupcol="geometry_position",
    title="Compton-region slope vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Slope ((counts/s)/ADC)",
)

grouped_line_plot(
    thickness_df,
    xcol="thickness_cm",
    ycol=length_col,
    groupcol="geometry_position",
    title="Compton-region length vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Length (ADC)",
)
# Out:
# Slope columns: ['compton_region_slope_counts_per_s_per_ADC__backscatter_peak', 'compton_region_slope_counts_per_s_per_ADC__compton_edge']
# Length columns: ['compton_region_length_ADC__backscatter_peak', 'compton_region_length_ADC__compton_edge', 'compton_region_length_ADC_err__backscatter_peak', 'compton_region_length_ADC_err__compton_edge']

# %%
# -----------------------------
# ANALYSIS 4: ORDINARY CS STABILITY CONTROLS
# -----------------------------

standard_df = analysis_df[analysis_df["geometry_position"] == "standard"].copy()
display(standard_df[[
    "file",
    "day",
    "center_ADC__backscatter_peak",
    "center_ADC__compton_edge",
    "photopeak_center_ADC",
]].sort_values("day"))

fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(standard_df["day"], standard_df["photopeak_center_ADC"], "o-", label="photopeak")
ax.plot(standard_df["day"], standard_df["center_ADC__compton_edge"], "o-", label="Compton edge")
ax.plot(standard_df["day"], standard_df["center_ADC__backscatter_peak"], "o-", label="backscatter")
ax.set_title("Ordinary Cs runs: feature-center stability by day")
ax.set_xlabel("Day")
ax.set_ylabel("ADC center")
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()
# Out:
#                                                 file    day  \
# 3  calibration/feb_24/preamp_0/Cs_22.1C_preamp0_f...  feb24
# 4    cs gain setting/Cs_possible_calcurve_feb_24.csv  feb24
# 6          data/feb_26/cs137/Cs_22.4C_feb26_run1.csv  feb26
# 7            data/mar_3/cs137/Cs_22.5C_mar3_run1.csv   mar3
# 8            data/mar_5/cs137/Cs_21.9C_mar5_run1.csv   mar5
# 0        calibration/daily/Cs_21.9C_preamp0_mar5.csv   None
# 1        calibration/daily/Cs_22.0C_preamp0_mar3.csv   None
# 2       calibration/daily/Cs_22.4C_preamp0_feb26.csv   None
# 5                cs gain setting/Cs_trial_feb_19.csv   None
#
#    center_ADC__backscatter_peak  center_ADC__compton_edge  \
# 3                    146.828851                332.599207
# 4                    144.965989                336.736137
# 6                    138.219695                333.658943
# 7                    154.441353                324.390000
# 8                    151.985613                354.748548
# 0                    152.635832                340.547030
# 1                    155.014473                354.746429
# 2                    143.535067                340.503966
# 5                    129.030000                261.376175
#
#    photopeak_center_ADC
# 3            505.196312
# 4                   NaN
# 6            503.190803
# 7            505.105909
# 8            505.214458
# 0            505.179638
# 1            505.671076
# 2            503.121706
# 5                   NaN
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 15
#       6 display(standard_df[[
#       7     "file",
#       8     "day",
#    (...)     11     "photopeak_center_ADC",
#      12 ]].sort_values("day"))
#      14 fig, ax = plt.subplots(figsize=(9, 5))
# ---> 15 ax.plot(standard_df["day"], standard_df["photopeak_center_ADC"], "o-", label="photopeak")
#      16 ax.plot(standard_df["day"], standard_df["center_ADC__compton_edge"], "o-", label="Compton edge")
#      17 ax.plot(standard_df["day"], standard_df["center_ADC__backscatter_peak"], "o-", label="backscatter")
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/axes/_base.py:489, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     486     x, y = index_of(xy[-1])
#     488 if axes.xaxis is not None:
# --> 489     axes.xaxis.update_units(x)
#     490 if axes.yaxis is not None:
#     491     axes.yaxis.update_units(y)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a None

# %% [markdown]
# ## One more analysis I think is worth doing
#
# For the ugly `in_front` runs where the 662 keV peak is effectively gone, add a **window-integration analysis** that does not rely on a visible photopeak.
#
# For each file, use the fitted backscatter and edge centers to define windows such as:
#
# - below backscatter,
# - around backscatter,
# - between backscatter and edge,
# - above edge.
#
# Then compare the fractional counts in each window as thickness changes. That gives you a much more stable observable when traditional peak fitting breaks down.

# %%
# -----------------------------
# OPTIONAL WINDOW-INTEGRATION ANALYSIS
# -----------------------------

def load_spectrum(csv_path):
    with open(csv_path, "r", encoding="utf-8", errors="replace") as f:
        lines = f.readlines()

    metadata = {}
    data_start_idx = None

    for i, line in enumerate(lines):
        stripped = line.strip()
        if stripped == "Channel Data:":
            data_start_idx = i + 1
            break
        if "Elapsed Real Time:" in stripped:
            value = stripped.split("Elapsed Real Time:", 1)[1]
            value = value.split(",", 1)[1].strip() if "," in value else value.strip()
            metadata["Elapsed Real Time"] = value

    if data_start_idx is None:
        raise RuntimeError(f"Could not locate channel data block in {csv_path}")

    df = pd.read_csv(csv_path, skiprows=data_start_idx, header=None, names=["channel", "energy", "counts"])
    df = df.dropna(subset=["channel", "counts"])

    x = pd.to_numeric(df["channel"], errors="coerce").to_numpy(float)
    y = pd.to_numeric(df["counts"], errors="coerce").to_numpy(float)

    rt = metadata.get("Elapsed Real Time", None)
    match = re.search(r"[-+]?\d*\.?\d+", str(rt))
    live_time_s = float(match.group()) if match else np.nan

    return x, y, live_time_s

def counts_to_rate(counts, live_time_s):
    return np.asarray(counts, dtype=float) / float(live_time_s)

def background_subtracted_rate(sample_relpath, background_path=BACKGROUND_FILE):
    sample_path = ROOT / sample_relpath
    x_s, y_s, t_s = load_spectrum(sample_path)
    x_b, y_b, t_b = load_spectrum(background_path)

    if len(x_s) != len(x_b) or not np.allclose(x_s, x_b):
        raise RuntimeError("Sample/background grid mismatch.")

    return x_s, counts_to_rate(y_s, t_s) - counts_to_rate(y_b, t_b)

def integrate_window(x, y, xmin, xmax):
    mask = (x >= xmin) & (x <= xmax)
    if not np.any(mask):
        return np.nan
    return np.trapz(y[mask], x[mask])

window_rows = []

for _, row in analysis_df.iterrows():
    file = row["file"]
    back = row["center_ADC__backscatter_peak"]
    edge = row["center_ADC__compton_edge"]

    if not (np.isfinite(back) and np.isfinite(edge) and edge > back):
        continue

    x, y = background_subtracted_rate(file)

    total = integrate_window(x, y, x.min(), x.max())
    low = integrate_window(x, y, 0, back - 0.5 * (edge - back))
    around_back = integrate_window(x, y, back - 15, back + 15)
    continuum = integrate_window(x, y, back, edge)
    above_edge = integrate_window(x, y, edge, min(edge + 150, x.max()))

    window_rows.append({
        "file": file,
        "low_fraction": low / total if total else np.nan,
        "backscatter_window_fraction": around_back / total if total else np.nan,
        "continuum_fraction": continuum / total if total else np.nan,
        "above_edge_fraction": above_edge / total if total else np.nan,
    })

window_df = pd.DataFrame(window_rows)
window_analysis_df = analysis_df.merge(window_df, on="file", how="left")
display(window_analysis_df.head(20))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 66
#      63 if not (np.isfinite(back) and np.isfinite(edge) and edge > back):
#      64     continue
# ---> 66 x, y = background_subtracted_rate(file)
#      68 total = integrate_window(x, y, x.min(), x.max())
#      69 low = integrate_window(x, y, 0, back - 0.5 * (edge - back))
#
# Cell In[17], line 46, in background_subtracted_rate(sample_relpath, background_path)
#      43 x_b, y_b, t_b = load_spectrum(background_path)
#      45 if len(x_s) != len(x_b) or not np.allclose(x_s, x_b):
# ---> 46     raise RuntimeError("Sample/background grid mismatch.")
#      48 return x_s, counts_to_rate(y_s, t_s) - counts_to_rate(y_b, t_b)
#
# RuntimeError: Sample/background grid mismatch.

# %%
# -----------------------------
# EXAMPLE WINDOW-FRACTION PLOTS
# -----------------------------

window_thickness_df = window_analysis_df[window_analysis_df["geometry_position"].isin(["behind", "in_front"])].copy()

grouped_line_plot(
    window_thickness_df,
    xcol="thickness_cm",
    ycol="backscatter_window_fraction",
    groupcol="geometry_position",
    title="Backscatter-window fraction vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Fraction of total background-subtracted counts",
)

grouped_line_plot(
    window_thickness_df,
    xcol="thickness_cm",
    ycol="continuum_fraction",
    groupcol="geometry_position",
    title="Compton-continuum fraction vs thickness",
    xlabel="Thickness (cm)",
    ylabel="Fraction of total background-subtracted counts",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       1 # -----------------------------
#       2 # EXAMPLE WINDOW-FRACTION PLOTS
#       3 # -----------------------------
# ----> 5 window_thickness_df = window_analysis_df[window_analysis_df["geometry_position"].isin(["behind", "in_front"])].copy()
#       7 grouped_line_plot(
#       8     window_thickness_df,
#       9     xcol="thickness_cm",
#    (...)     14     ylabel="Fraction of total background-subtracted counts",
#      15 )
#      17 grouped_line_plot(
#      18     window_thickness_df,
#      19     xcol="thickness_cm",
#    (...)     24     ylabel="Fraction of total background-subtracted counts",
#      25 )
#
# NameError: name 'window_analysis_df' is not defined
